# %%
# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython
# # distutils: language = c++
#
# from libcpp.vector cimport vector
# from libc.string cimport memcpy
# from libc.stdlib cimport malloc, free
# from numpy cimport ndarray, uint8_t
# from numpy import copy, asarray, ascontiguousarray, uint8
# from opencv_cmat.opencv_mat cimport *
# ctypedef unsigned char uchar
#
#
# cdef class CopyNumpyArray:
#     cdef:
#         vector[vector[vector[Mat]]] mat_arrays
#         int dim,dim1,r,c
#     def __cinit__(self, uchar[:,:,:,:] data, int copies):
#         self.dim = data.shape[0]
#         self.dim1 = data.shape[1]
#         self.r = data.shape[2]
#         self.c = data.shape[3]
#
#         self.copy_imgArray(data, copies)
#
#     cdef Mat np2Mat2D(self, uchar[:,:] data):
#         assert (data.ndim==2), "ASSERT::1 channel grayscale only!!"
#
#         cdef ndarray[uint8_t, ndim=2, mode ='c'] np_buff = ascontiguousarray(data, dtype=uint8)
#         cdef unsigned int* im_buff = <unsigned int*> np_buff.data
#
#         cdef Mat m
#         m.create(self.r, self.c, CV_8UC1)
#         memcpy(m.data, im_buff, self.r*self.c)
#         return m
#     cdef void copy_imgArray(self, uchar[:,:,:,:] data, int copies ):
#         cdef:
#             int i,j
#             Mat img
#             Mat copied
#             vector[vector[Mat]] imgs
#             vector[Mat] copies
#
#         for i in range(self.dim):
#             for j in range(self.dim1):
#                 img = self.np2Mat2D(data[i,j,:,:])
#                 for _ in range(copies):
#                     copied = img.clone()
#                     copies.push_back(copied)
#                 imgs.push_back(copies)
#             self.mat_arrays.push_back(imgs)
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.vector cimport vector
# from libc.string cimport memcpy
# from libc.stdlib cimport malloc, free
# from numpy cimport ndarray, uint8_t
# from numpy import copy, asarray, ascontiguousarray, uint8
# from .opencv_cmat.opencv_mat cimport *
# ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:8:0: relative cimport beyond main package is not allowed
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# ctypedef unsigned char uchar
#
#
# cdef class CopyNumpyArray:
#     cdef:
#         vector[vector[vector[Mat]]] mat_arrays
#                                ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:14:32: unknown type in template argument
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.r = data.shape[2]
#         self.c = data.shape[3]
#
#         self.copy_imgArray(data, copies)
#
#     cdef Mat np2Mat2D(self, uchar[:,:] data):
#         ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:24:9: 'Mat' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         assert (data.ndim==2), "ASSERT::1 channel grayscale only!!"
#
#         cdef ndarray[uint8_t, ndim=2, mode ='c'] np_buff = ascontiguousarray(data, dtype=uint8)
#         cdef unsigned int* im_buff = <unsigned int*> np_buff.data
#
#         cdef Mat m
#             ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:30:13: 'Mat' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         memcpy(m.data, im_buff, self.r*self.c)
#         return m
#     cdef void copy_imgArray(self, uchar[:,:,:,:] data, int copies ):
#         cdef:
#             int i,j
#             Mat img
#            ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:37:12: 'Mat' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return m
#     cdef void copy_imgArray(self, uchar[:,:,:,:] data, int copies ):
#         cdef:
#             int i,j
#             Mat img
#             Mat copied
#            ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:38:12: 'Mat' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef void copy_imgArray(self, uchar[:,:,:,:] data, int copies ):
#         cdef:
#             int i,j
#             Mat img
#             Mat copied
#             vector[vector[Mat]] imgs
#                             ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:39:29: unknown type in template argument
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         cdef:
#             int i,j
#             Mat img
#             Mat copied
#             vector[vector[Mat]] imgs
#             vector[Mat] copies
#                      ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:40:22: unknown type in template argument
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         cdef:
#             int i,j
#             Mat img
#             Mat copied
#             vector[vector[Mat]] imgs
#             vector[Mat] copies
#                        ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:40:24: 'copies' redeclared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         cdef Mat m
#         m.create(self.r, self.c, CV_8UC1)
#         memcpy(m.data, im_buff, self.r*self.c)
#         return m
#     cdef void copy_imgArray(self, uchar[:,:,:,:] data, int copies ):
#                                                       ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:34:55: Previous declaration is here
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         cdef ndarray[uint8_t, ndim=2, mode ='c'] np_buff = ascontiguousarray(data, dtype=uint8)
#         cdef unsigned int* im_buff = <unsigned int*> np_buff.data
#
#         cdef Mat m
#         m.create(self.r, self.c, CV_8UC1)
#                                 ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:31:33: undeclared name not builtin: CV_8UC1
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         cdef ndarray[uint8_t, ndim=2, mode ='c'] np_buff = ascontiguousarray(data, dtype=uint8)
#         cdef unsigned int* im_buff = <unsigned int*> np_buff.data
#
#         cdef Mat m
#         m.create(self.r, self.c, CV_8UC1)
#         memcpy(m.data, im_buff, self.r*self.c)
#                ^
# ------------------------------------------------------------
#
# /home/cristian/.cache/ipython/cython/_cython_magic_4b4b7d980bdd83914b2fb7e5c99ddb80.pyx:32:16: Cannot convert Python object to 'void *'
